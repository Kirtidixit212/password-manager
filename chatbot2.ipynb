# %% [markdown]
# <a href="https://colab.research.google.com/github/Kirtidixit212/Kirtidixit212/blob/main/chatbot2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Description:This is a Chat bot program

# %%
#import the library
from nltk.chat.util import Chat, reflections

# %%
pairs = [
    ['my name is (.*)', ['hi %1']],
    ['(hi|hello|hey|holla|hola)',['hey there', 'hi there','haayyy']],
    ['(.*) in (.*) is fun',['%1 in %2 is indeed fun']],
    ['(.*)(location|city) ?', ['Tokyo, Japan']],
    ['(.*) created you?',['kirtidixit211 did using NLTK']],
    ['how is the weather in (.*)', ['the weather in %1 is amazing like always']],
    ['(.*) help (.*)', ['I can help you']],

]

# %%
reflections

# %%
my_dummy_reflections = {
    'go' : 'gone',
    'hello' : 'hey there'
}

# %%
chat = Chat(pairs, my_dummy_reflections)
# chat._substitute('go hello')
chat.converse()
# Out:
# >what is your name?
# None
# >please help me
# I can help you
# >what is your name?
# None
